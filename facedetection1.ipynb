# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/saiyamarora/opt/anaconda3/lib/python3.9/site-packages (4.5.5.64)
# Requirement already satisfied: numpy>=1.19.3 in /Users/saiyamarora/opt/anaconda3/lib/python3.9/site-packages (from opencv-python) (1.20.3)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = plt.imread("./group-photo.jpg")

# %%
img.shape
# Out:
# (500, 700, 3)

# %%
plt.imshow(img)

# %%
detector = cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')

# %%
all_faces = detector.detectMultiScale(img,1.3,5)

# %%
all_faces.shape
# Out:
# (5, 4)

# %%
x,y,w,h = all_faces[0]

# %%
img = cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0),2)

# %%
plt.imshow(img)

# %%
# plotting rectangle for all faces
for face in all_faces:
    x,y,w,h = face
    img = cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0),2)

# %%
plt.imshow(img)
